# %% [markdown]
# ##**Exploratory Data Analysis of US accidents**

# %%
import jovian
jovian.set_project('us-accidents-analysis')
jovian.set_colab_id('1LluLT2vS1L3GfoIPHyBPbzvhJz5xIQz1')

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %% [markdown]
# ##Downloading dataset

# %%
pip install opendatasets --upgrade

# %%
import opendatasets as od

# %%
download_url = 'https://www.kaggle.com/sobhanmoosavi/us-accidents'

# %%
od.download(download_url)
# Out:
# Skipping, found downloaded files in "./us-accidents" (use force=True to force download)

# %%
data_filename = '/content/us-accidents/US_Accidents_Dec20_updated.csv'

# %% [markdown]
# ##Data preparation and Cleaning
# 1-Load file using Pandas
# 2-Analyze file
# 3-Fix incorrect or missing value

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename)

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df)
# Out:
# 1516064

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516064 entries, 0 to 1516063
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1516064 non-null  object
#  1   Severity               1516064 non-null  int64
#  2   Start_Time             1516064 non-null  object
#  3   End_Time               1516064 non-null  object
#  4   Start_Lat              1516064 non-null  float64
#  5   Start_Lng              1516064 non-null  float64
#  6   End_Lat                1516064 non-null  float64
#  7   End_Lng                1516064 non-null  float64
#  8   Distance(mi)           1516064 non-null  float64
#  9   Description            1516064 non-null  object
#  10  Number                 469969 non-null   float64
#  11  Street                 1516064 non-null  object
#  12  Side                   1516064 non-null  object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  1.516064e+06  1.516064e+06  ...     1.387202e+06       1.005515e+06
# mean   2.238630e+00  3.690056e+01  ...     7.630812e+00       8.477855e-03
# std    6.081481e-01  5.165653e+00  ...     5.637364e+00       1.293168e-01
# min    1.000000e+00  2.457022e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.385422e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.735113e+01  ...     7.000000e+00       0.000000e+00
# 75%    2.000000e+00  4.072593e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900058e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
  df.isnull()
# Out:
#             ID  Severity  ...  Nautical_Twilight  Astronomical_Twilight
# 0        False     False  ...              False                  False
# 1        False     False  ...              False                  False
# 2        False     False  ...              False                  False
# 3        False     False  ...              False                  False
# 4        False     False  ...              False                  False
# ...        ...       ...  ...                ...                    ...
# 1516059  False     False  ...              False                  False
# 1516060  False     False  ...              False                  False
# 1516061  False     False  ...              False                  False
# 1516062  False     False  ...              False                  False
# 1516063  False     False  ...              False                  False
#
# [1516064 rows x 47 columns]

# %%
df.isna()
# Out:
#             ID  Severity  ...  Nautical_Twilight  Astronomical_Twilight
# 0        False     False  ...              False                  False
# 1        False     False  ...              False                  False
# 2        False     False  ...              False                  False
# 3        False     False  ...              False                  False
# 4        False     False  ...              False                  False
# ...        ...       ...  ...                ...                    ...
# 1516059  False     False  ...              False                  False
# 1516060  False     False  ...              False                  False
# 1516061  False     False  ...              False                  False
# 1516062  False     False  ...              False                  False
# 1516063  False     False  ...              False                  False
#
# [1516064 rows x 47 columns]

# %% [markdown]
# sum of missing value in data

# %%
df.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1046095
# Street                         0
# Side                           0
# City                          83
# County                         0
# State                          0
# Zipcode                      935
# Country                        0
# Timezone                    2302
# Airport_Code                4248
# Weather_Timestamp          30264
# Temperature(F)             43033
# Wind_Chill(F)             449316
# Humidity(%)                45509
# Pressure(in)               36274
# Visibility(mi)             44211
# Wind_Direction             41858
# Wind_Speed(mph)           128862
# ...

# %%
len(df)
# Out:
# 1516064

# %% [markdown]
# percentage of missing value per *column*

# %%
 missing_percentages = df.isna().sum().sort_values(ascending=False) /len(df)
 missing_percentages
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# City                     0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# Civil_Twilight           0.000055
# Sunrise_Sunset           0.000055
# Amenity                  0.000000
# Bump                     0.000000
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# End_Lat                  0.000000
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
 missing_percentages.plot(kind='barh')

# %%
 missing_percentages != 0
# Out:
# Number                    True
# Precipitation(in)         True
# Wind_Chill(F)             True
# Wind_Speed(mph)           True
# Humidity(%)               True
# Visibility(mi)            True
# Weather_Condition         True
# Temperature(F)            True
# Wind_Direction            True
# Pressure(in)              True
# Weather_Timestamp         True
# Airport_Code              True
# Timezone                  True
# Zipcode                   True
# City                      True
# Nautical_Twilight         True
# Astronomical_Twilight     True
# Civil_Twilight            True
# Sunrise_Sunset            True
# Amenity                  False
# Bump                     False
# Severity                 False
# Start_Time               False
# End_Time                 False
# Start_Lat                False
# Start_Lng                False
# End_Lat                  False
# End_Lng                  False
# Distance(mi)             False
# Description              False
# ...

# %%
missing_percentages[missing_percentages != 0]
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# City                     0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# Civil_Twilight           0.000055
# Sunrise_Sunset           0.000055
# dtype: float64

# %%
  missing_percentages[missing_percentages != 0].plot(kind="barh")

# %% [markdown]
# Removing column which has more then half missing value

# %% [markdown]
# ##Exploratory Analysis and Visualization
# column to analyze
# 1. city
# 2. Start Time
# 3. Start Lat,Start Lng
# 4. Temperature
# 5. Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
  df.City
# Out:
# 0               Dublin
# 1               Dayton
# 2           Cincinnati
# 3           Cincinnati
# 4                Akron
#               ...
# 1516059      Riverside
# 1516060      San Diego
# 1516061         Orange
# 1516062    Culver City
# 1516063       Highland
# Name: City, Length: 1516064, dtype: object

# %%
len(df.City)
# Out:
# 1516064

# %%
df.City.unique()
# Out:
# array(['Dublin', 'Dayton', 'Cincinnati', ..., 'Succasunna', 'Valleyford',
#        'American Fork-Pleasant Grove'], dtype=object)

# %%
cities = df.City.unique()
len(cities)
# Out:
# 10658

# %%
cities[0:200]
# Out:
# array(['Dublin', 'Dayton', 'Cincinnati', 'Akron', 'Williamsburg',
#        'Batavia', 'Cleveland', 'Lima', 'Westerville', 'Jamestown',
#        'Freeport', 'Columbus', 'Toledo', 'Roanoke', 'Ft Mitchell',
#        'Edinburgh', 'Fairborn', 'Shelbyville', 'Greensburg', 'Saint Paul',
#        'Parkersburg', 'Indianapolis', 'Dundee', 'Jeffersonville',
#        'Pittsburgh', 'Lewis Center', 'Dunkirk', 'Redkey', 'Milton',
#        'Willshire', 'Straughn', 'Cambridge Springs', 'Fremont',
#        'Louisville', 'South Charleston', 'Edinboro', 'Buckhannon',
#        'Lockbourne', 'Painesville', 'Washington', 'Dunbar', 'Angola',
#        'Edon', 'Medina', 'De Mossville', 'New Albany', 'Charleston',
#        'Fort Wayne', 'Burnsville', 'Bedford', 'Clarksville', 'Lakewood',
#        'Richfield', 'Sewickley', 'Independence', 'Westlake', 'Erlanger',
#        'Grove City', 'Monroe', 'West Middlesex', 'Gaston', 'Economy',
#        'Fairmount', 'Hagerstown', 'Walton', 'Crittenden', 'Coraopolis',
# ...

# %%
cities_by_accidents = df.City.value_counts()

# %%
cities_by_accidents
# Out:
# Los Angeles    39984
# Miami          36233
# Charlotte      22203
# Houston        20843
# Dallas         19497
#                ...
# Braidwood          1
# Manistique         1
# Beckville          1
# Baird              1
# Prosper            1
# Name: City, Length: 10657, dtype: int64

# %%
"New york" in df.City
# Out:
# False

# %%
cities_by_accidents[0:15].plot(kind='barh')

# %%
import seaborn as sns

# %%
sns.distplot(cities_by_accidents)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
  [cities_by_accidents]
# Out:
# [Los Angeles    39984
#  Miami          36233
#  Charlotte      22203
#  Houston        20843
#  Dallas         19497
#                 ...
#  Braidwood          1
#  Manistique         1
#  Beckville          1
#  Baird              1
#  Prosper            1
#  Name: City, Length: 10657, dtype: int64]

# %%
high_accident_cities = cities_by_accidents[cities_by_accidents>1000]
high_accident_cities
# Out:
# Los Angeles    39984
# Miami          36233
# Charlotte      22203
# Houston        20843
# Dallas         19497
#                ...
# Elgin           1007
# Chandler        1006
# Palo Alto       1006
# Flushing        1001
# Sandy           1001
# Name: City, Length: 251, dtype: int64

# %%
low_accident_cities = cities_by_accidents[cities_by_accidents<1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.023550384687558643

# %%
sns.distplot(high_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 sns.distplot(low_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
    cities_by_accidents[cities_by_accidents==1]
# Out:
# Webb City          1
# Keokuk             1
# Copperhill         1
# Sherwood Forest    1
# Holmen             1
#                   ..
# Braidwood          1
# Manistique         1
# Beckville          1
# Baird              1
# Prosper            1
# Name: City, Length: 1167, dtype: int64

# %% [markdown]
# ###Start time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 00:37:08
# 1          2016-02-08 05:56:20
# 2          2016-02-08 06:15:39
# 3          2016-02-08 06:15:39
# 4          2016-02-08 06:51:45
#                   ...
# 1516059    2019-08-23 18:03:25
# 1516060    2019-08-23 19:11:30
# 1516061    2019-08-23 19:00:21
# 1516062    2019-08-23 19:00:21
# 1516063    2019-08-23 18:52:06
# Name: Start_Time, Length: 1516064, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 00:37:08'

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
   type(df.Start_Time)
# Out:
# pandas.core.series.Series

# %%
  df.Start_Time.dt.hour
# Out:
# 0           0
# 1           5
# 2           6
# 3           6
# 4           6
#            ..
# 1516059    18
# 1516060    19
# 1516061    19
# 1516062    19
# 1516063    18
# Name: Start_Time, Length: 1516064, dtype: int64

# %%
   sns.histplot(df.Start_Time.dt.hour, bins=24)

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24,kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# -high percentage of accident occured during 3pm-5pm
# - next highest frequent accident time 7am-8am (may be people in hurry to go for work)

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# kde is kernel density estimation. it used for automatic bandwidth determination.

# %% [markdown]
# 1. on weekends the number of accidents are lower.
# 2. 6 is sunday and 0 is monday here

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek ==6]

# %%
sns.distplot(sundays_start_time.dt.hour, bins=24, kde= False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1. peak occurs during evening as people migh going for marketing after sunset
# 2. on sudays second  most accidents occur timing during (00:oo to 01:00)am as maybe people drunk and drive after saturday night.

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]

# %%
sns.distplot(monday_start_time.dt.hour, bins = 24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# on mondays durig 3 pm to 5 pm is peak

# %%
sns.distplot(monday_start_time.dt.month, bins = 12, kde= False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# toward the end of year accident rate is high as that month is their festival month (Holloween, Christmas)

# %%
df.Start_Time.dt.year
# Out:
# 0          2016
# 1          2016
# 2          2016
# 3          2016
# 4          2016
#            ...
# 1516059    2019
# 1516060    2019
# 1516061    2019
# 1516062    2019
# 1516063    2019
# Name: Start_Time, Length: 1516064, dtype: int64

# %% [markdown]
# 2020 data is missing

# %%
 df_2019 = df.Start_Time.dt.year == 2019

# %%
sns.distplot(df.Start_Time.dt.month, bins= 12, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Start latitude and longitude

# %%
df.Start_Lat
# Out:
# 0          40.10891
# 1          39.86542
# 2          39.10266
# 3          39.10148
# 4          41.06213
#              ...
# 1516059    34.00248
# 1516060    32.76696
# 1516061    33.77545
# 1516062    33.99246
# 1516063    34.13393
# Name: Start_Lat, Length: 1516064, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.09286
# 1          -84.06280
# 2          -84.52468
# 3          -84.52341
# 4          -81.53784
#              ...
# 1516059   -117.37936
# 1516060   -117.14806
# 1516061   -117.84779
# 1516062   -118.40302
# 1516063   -117.23092
# Name: Start_Lng, Length: 1516064, dtype: float64

# %%
sns.scatterplot(x=df.Start_Lng , y= df.Start_Lat)

# %%
sample_df = df.sample(int(0.1*len(df)))

# %% [markdown]
# we have now 10% of sample in sample_df

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat,size = 0.001)

# %% [markdown]
# mojority of accidents did't occure in mid of us.

# %% [markdown]
# ##Summary and conclusion
# 1. No data from Newyork
# 2. Most of the Accident occure from 3pm to 5pm during working days(mon-sat).
# 3. 2020 data is missing in this dataset
# 4. In december,the accident rate is more then any other month as people might be in rush in festival season(Holloween,Christmas) to celebrate and meetup.
# 4. most of the holidays are in december in us so above average population might be driving to go on vacation or to party.
# 5. on weekends the accident  rate are lower .
# 6. On sunday the most accident occure during evening time as people might be going to hangout.
# 7. Second peak of accident on sunday is between 900:00-01:00) as people might be returning home after party in drunk condition.
# 8. 1167 city reported just 1 accident.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY: ··········
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/pandey23/us-accidents-analysis
# 'https://jovian.ai/pandey23/us-accidents-analysis'
